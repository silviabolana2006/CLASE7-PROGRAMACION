# %%
def saludo():
    print("bienvenido al sistema")

# %%
saludo()
# Out:
# bienvenido al sistema

# %%
def saludo(nombre):
    print("bienvenido al sistema",nombre)

# %%
saludo("silvia")
# Out:
# bienvenido al sistema silvia

# %%
def division(dividendo=15):
    divisor=3
    return dividendo/divisor

division()
# Out:
# 5.0

# %%
division(2)
# Out:
# 0.6666666666666666

# %%
def operacion1(num, num1):
    return num*num1

# %%
resultado=operacion1(7,5)
if resultado >40:
    print("el resultado es mayor",resultado)
else:
    print("el resultado",resultado,"es menor a 40")
# Out:
# el resultado 35 es menor a 40

# %%
def obtener_datos_persona():
    nombre="silvia"
    apellido="bolaña"
    edad=17
    domicilio= "gorriti 378"
    return nombre, apellido, edad, domicilio

# %%
persona=obtener_datos_persona()
print(persona)
print(type(persona))
# Out:
# ('silvia', 'bolaña', 17, 'gorriti 378')
# <class 'tuple'>

# %%
nombre,apellido,edad,domicilio=persona

# %%
print(f"el nombre ingrasado es {nombre}")
# Out:
# el nombre ingrasado es silvia

# %%
print(f"el apellido ingresado es{apellido}")
# Out:
# el apellido ingresado esbolaña

# %%
if edad>18:
    print(f"usted es mayor de edad.usted tiene{edad}años")
else:
    print(f"no puede acceder por ser menor de edad. tiene {edad} años")
# Out:
# no puede acceder por ser menor de edad. tiene 17 años

# %%
def dato_persona(nombre, apellido):
    print("hola",nombre, apellido)

# %%
dato_persona("silvia","bolaña")
# Out:
# hola silvia bolaña

# %% [markdown]
# funciones con muchos argunebtos sin explicitar
